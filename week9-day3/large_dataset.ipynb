# %%
import pandas as pd
import seaborn as sns
# Load your large dataset
df = sns.load_dataset('iris')

# Sample a fraction of the data
sampled_df = df.sample(frac=0.1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sampled_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 27            5.2          3.5           1.5          0.2      setosa
# 87            6.3          2.3           4.4          1.3  versicolor
# 44            5.1          3.8           1.9          0.4      setosa
# 144           6.7          3.3           5.7          2.5   virginica
# 68            6.2          2.2           4.5          1.5  versicolor
# 30            4.8          3.1           1.6          0.2      setosa
# 147           6.5          3.0           5.2          2.0   virginica
# 139           6.9          3.1           5.4          2.1   virginica
# 137           6.4          3.1           5.5          1.8   virginica
# 40            5.0          3.5           1.3          0.3      setosa
# 110           6.5          3.2           5.1          2.0   virginica
# 143           6.8          3.2           5.9          2.3   virginica
# ...

# %%
dask_df.loc[0:1]
# Out:
# Dask DataFrame Structure:
#               sepal_length sepal_width petal_length petal_width species
# npartitions=1
# 0                  float64     float64      float64     float64  object
# 1                      ...         ...          ...         ...     ...
# Dask Name: loc, 2 graph layers

# %%
import dask.dataframe as dd

# Convert a pandas DataFrame to a Dask DataFrame
dask_df = dd.from_pandas(df, npartitions=10)

# Perform operations similar to pandas
result = dask_df.groupby('species').mean()

# %%
result
# Out:
# Dask DataFrame Structure:
#               sepal_length sepal_width petal_length petal_width
# npartitions=1
#                    float64     float64      float64     float64
#                        ...         ...          ...         ...
# Dask Name: truediv, 7 graph layers

# %%
import matplotlib.pyplot as plt

# Assuming 'sampled_df' is a sampled pandas DataFrame
plt.scatter(sampled_df['sepal_length'], sampled_df['sepal_width'])
plt.show()

# %%
df.plot.hexbin(x='sepal_length', y='sepal_width', gridsize=30)
plt.show()

# %%
from bokeh.plotting import figure, show

# Create a basic interactive plot
p = figure(title="Large dataset visualization with Bokeh")
p.circle(sampled_df['sepal_length'], sampled_df['sepal_width'], size=10)

show(p)
