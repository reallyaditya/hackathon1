# %%
from plotnine import ggplot, aes, geom_point
import pandas as pd

# Sample data
data = pd.DataFrame({'x': [1, 2, 3, 4, 5], 'y': [3, 5, 2, 6, 4]})
data
# Out:
#    x  y
# 0  1  3
# 1  2  5
# 2  3  2
# 3  4  6
# 4  5  4

# %%
# Creating a scatter plot
(ggplot(data, aes(x='x', y='y')) + geom_point())

# %%
from plotnine import geom_smooth

# Adding a smooth line layer
(ggplot(data, aes(x='x', y='y')) + 
 geom_point() + 
 geom_smooth(method='lm'))

# %%
import pandas as pd
import numpy as np

from plotnine import ggplot, aes, geom_point, scale_color_manual# Set random seed for reproducibility
np.random.seed(42)# Generate example data

x = np.linspace(1, 10, 200)
y = 2 * x + np.random.normal(0, 2, 200)# Create a categorical variable

category = np.random.choice(['A', 'B', 'C'], size=200)# Create a DataFrame

data = pd.DataFrame({'x': x, 'y': y, 'category': category})# Plot with customized colors
data
# Out:
#              x          y category
# 0     1.000000   2.993428        B
# 1     1.045226   1.813924        B
# 2     1.090452   3.476282        A
# 3     1.135678   5.317416        A
# 4     1.180905   1.893502        A
# ..         ...        ...      ...
# 195   9.819095  20.408826        A
# 196   9.864322  17.960928        C
# 197   9.909548  20.126546        A
# 198   9.954774  20.025965        C
# 199  10.000000  17.714059        A
#
# [200 rows x 3 columns]

# %%
plot = (ggplot(data, aes(x='x', y='y', color='category')) +
        geom_point() +
        scale_color_manual(values=["blue", "green", "red"]))# Display the plot

print(plot)
# Out:
# /var/folders/1q/8fg47jsn3_3706q0g9gvxkp40000gn/T/ipykernel_71164/3200262300.py:5: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().

# %%
from plotnine import theme_light

(ggplot(data, aes(x='x', y='y')) + 
 geom_point() + 
 theme_light())

# %%
data.groupby('category').size()
# Out:
# category
# A    74
# B    70
# C    56
# dtype: int64

# %%
from plotnine import facet_wrap

# Assuming 'category' is a column in your DataFrame
(ggplot(data, aes(x='x', y='y')) + 
 geom_point() + 
 facet_wrap('~category'))

# %%
from plotnine import geom_histogram

(ggplot(data, aes(x='x')) + 
 geom_histogram(binwidth=1))

# %%
# Assuming 'df' is a pandas DataFrame
df = pd.read_csv("/Users/aditya/Projects/dev_institute/week 7/week8-day7/sales_data.csv")
(ggplot(df, aes(x='category', y='revenue')) +
 geom_point())
# Out:
# /Users/aditya/Projects/dev_institute/week 7/.venv/lib/python3.11/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 1 rows containing missing values.
