# %%
import pandas as pd

weather_data = pd.read_csv('weatherHistory.csv')

# %%
weather_data
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01 00:00:00+02:00  Partly Cloudy        rain         9.472222
# 1      2006-04-01 01:00:00+02:00  Partly Cloudy        rain         9.355556
# 2      2006-04-01 02:00:00+02:00  Mostly Cloudy        rain         9.377778
# 3      2006-04-01 03:00:00+02:00  Partly Cloudy        rain         8.288889
# 4      2006-04-01 04:00:00+02:00  Mostly Cloudy        rain         8.755556
# ...                          ...            ...         ...              ...
# 96448  2016-09-09 19:00:00+02:00  Partly Cloudy        rain        26.016667
# 96449  2016-09-09 20:00:00+02:00  Partly Cloudy        rain        24.583333
# 96450  2016-09-09 21:00:00+02:00  Partly Cloudy        rain        22.038889
# 96451  2016-09-09 22:00:00+02:00  Partly Cloudy        rain        21.522222
# 96452  2016-09-09 23:00:00+02:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
weather_data['Formatted Date'] = pd.to_datetime(weather_data['Formatted Date'])
# Out:
# /var/folders/1q/8fg47jsn3_3706q0g9gvxkp40000gn/T/ipykernel_60222/1079356682.py:1: FutureWarning: In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`
#   weather_data['Formatted Date'] = pd.to_datetime(weather_data['Formatted Date'])

# %%
weather_data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
weather_data['Temperature_normalized'] = scaler.fit_transform(weather_data[['Temperature (C)']])

# %%
weather_data['Temperature_normalized'].describe()
# Out:
# count    96453.000000
# mean         0.546835
# std          0.154737
# min          0.000000
# 25%          0.429484
# 50%          0.547925
# 75%          0.658717
# max          1.000000
# Name: Temperature_normalized, dtype: float64

# %%
weather_data
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0      2006-04-01 00:00:00+02:00  Partly Cloudy        rain         9.472222
# 1      2006-04-01 01:00:00+02:00  Partly Cloudy        rain         9.355556
# 2      2006-04-01 02:00:00+02:00  Mostly Cloudy        rain         9.377778
# 3      2006-04-01 03:00:00+02:00  Partly Cloudy        rain         8.288889
# 4      2006-04-01 04:00:00+02:00  Mostly Cloudy        rain         8.755556
# ...                          ...            ...         ...              ...
# 96448  2016-09-09 19:00:00+02:00  Partly Cloudy        rain        26.016667
# 96449  2016-09-09 20:00:00+02:00  Partly Cloudy        rain        24.583333
# 96450  2016-09-09 21:00:00+02:00  Partly Cloudy        rain        22.038889
# 96451  2016-09-09 22:00:00+02:00  Partly Cloudy        rain        21.522222
# 96452  2016-09-09 23:00:00+02:00  Partly Cloudy        rain        20.438889
#
# ...

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=3)
reduced_data = pca.fit_transform(weather_data[['Temperature_normalized', 'Humidity', 'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)', 'Pressure (millibars)']])

# %%
pd.DataFrame(reduced_data)
# Out:
#                0           1         2
# 0       7.570809   64.181260  3.411643
# 1       7.527859   72.197510  3.502803
# 2      11.591029   17.277257 -6.492720
# 3       7.629942   82.226099  3.276542
# 4       8.416445   72.236244  0.300073
# ...          ...         ...       ...
# 96448  21.699798 -155.380957  1.831426
# 96449  23.244135 -166.308280  0.958731
# 96450  23.071107 -156.303673 -0.162559
# 96451  24.032001 -166.250889  1.444689
# 96452  22.970029 -147.311953 -3.371202
#
# [96453 rows x 3 columns]

# %%
average_temperature_by_precipitation = weather_data.groupby('Precip Type')['Temperature (C)'].mean()
average_temperature_by_precipitation.to_frame()
# Out:
#              Temperature (C)
# Precip Type
# rain               13.852989
# snow               -3.270885

# %%
average_temperature_by_precipitation.to_csv('average_temperature_by_precipitation.csv')
